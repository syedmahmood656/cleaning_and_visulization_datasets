# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import numpy as np

# %%
import seaborn.objects as so

# %%
df = pd.read_csv("loan_approval.csv")

# %%
df.sample(5)
# Out:
#                  name             city  income  credit_score  loan_amount  \
# 623      Jared George        Murphyton   33101           392        15261
# 1530    Colton Lawson    Reynoldsburgh   50232           799        44633
# 363       James Burns  Christopherside  102132           696        13116
# 1318   Hannah Oconnor         Laratown  109129           464        21907
# 859   Kristine Turner         Haleberg   84377           586        29309
#
#       years_employed  points  loan_approved
# 623                8    20.0          False
# 1530               3    60.0           True
# 363               23    80.0           True
# 1318               8    50.0          False
# 859               13    60.0           True

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   name            2000 non-null   object
#  1   city            2000 non-null   object
#  2   income          2000 non-null   int64
#  3   credit_score    2000 non-null   int64
#  4   loan_amount     2000 non-null   int64
#  5   years_employed  2000 non-null   int64
#  6   points          2000 non-null   float64
#  7   loan_approved   2000 non-null   bool
# dtypes: bool(1), float64(1), int64(4), object(2)
# memory usage: 111.5+ KB

# %%
df['city'].nunique()
# Out:
# 1882

# %%
df['years_employed'].nunique()
# Out:
# 41

# %%
p = so.Plot(df, "income", "loan_amount", color="loan_approved")
(
    p
    .add(so.Dash(), so.Agg(), so.Dodge())
    .add(so.Dots(), so.Dodge(), so.Jitter())
)

# %%
p = so.Plot(df, "income", "loan_amount", color="loan_approved")
p.add(so.Dash(), so.Dodge())

# %%
(
    df
    .rename_axis(index="credit_score")
    .pipe(so.Plot, x="loan_amount", ymin="years_employed", ymax="credit_score")
    .add(so.Range(), color="loan_approved")
)

# %%
df.head()
# Out:
#               name              city  income  credit_score  loan_amount  \
# 0     Allison Hill         East Jill  113810           389        39698
# 1     Brandon Hall     New Jamesside   44592           729        15446
# 2     Rhonda Smith      Lake Roberto   33278           584        11189
# 3  Gabrielle Davis  West Melanieview  127196           344        48823
# 4     Valerie Gray         Mariastad   66048           496        47174
#
#    years_employed  points  loan_approved
# 0              27    50.0          False
# 1              28    55.0          False
# 2              13    45.0          False
# 3              29    50.0          False
# 4               4    25.0          False
