# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('kaggle_Interests_group.csv')

# %%
df.head()
# Out:
#   group  grand_tot_interests  interest1  interest2  interest3  interest4  \
# 0     C                   17        NaN        NaN        NaN        NaN
# 1     C                   43        1.0        NaN        NaN        NaN
# 2     C                   27        NaN        NaN        NaN        NaN
# 3     C                   34        NaN        NaN        NaN        NaN
# 4     C                   36        NaN        NaN        NaN        NaN
#
#    interest5  interest6  interest7  interest8  ...  interest208  interest209  \
# 0        NaN        NaN        NaN        NaN  ...          NaN          NaN
# 1        1.0        NaN        NaN        NaN  ...          NaN          NaN
# 2        NaN        NaN        NaN        NaN  ...          NaN          NaN
# 3        NaN        NaN        NaN        NaN  ...          NaN          NaN
# 4        1.0        NaN        NaN        NaN  ...          NaN          NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6340 entries, 0 to 6339
# Columns: 219 entries, group to interest217
# dtypes: float64(217), int64(1), object(1)
# memory usage: 10.6+ MB

# %%
df.isnull().sum()
# Out:
# group                     0
# grand_tot_interests       0
# interest1              5347
# interest2              6339
# interest3              6305
#                        ...
# interest213            6338
# interest214            6268
# interest215            1397
# interest216            2282
# interest217            6193
# Length: 219, dtype: int64

# %%
df.isnull().sum()/100
# Out:
# group                   0.00
# grand_tot_interests     0.00
# interest1              53.47
# interest2              63.39
# interest3              63.05
#                        ...
# interest213            63.38
# interest214            62.68
# interest215            13.97
# interest216            22.82
# interest217            61.93
# Length: 219, dtype: float64

# %%
df.describe()
# Out:
#        grand_tot_interests  interest1  interest2  interest3  interest4  \
# count          6340.000000      993.0        1.0       35.0       25.0
# mean             37.312303        1.0        1.0        1.0        1.0
# std              15.729872        0.0        NaN        0.0        0.0
# min               1.000000        1.0        1.0        1.0        1.0
# 25%              28.000000        1.0        1.0        1.0        1.0
# 50%              39.000000        1.0        1.0        1.0        1.0
# 75%              48.000000        1.0        1.0        1.0        1.0
# max             104.000000        1.0        1.0        1.0        1.0
#
#         interest5    interest6  interest7  interest8   interest9  ...  \
# count  798.000000  3394.000000        1.0       93.0  333.000000  ...
# mean     1.001253     1.000589        1.0        1.0    1.003003  ...
# std      0.035400     0.024271        NaN        0.0    0.054800  ...
# ...

# %%
df.dropna()
# Out:
# Empty DataFrame
# ...

# %%
df.sample(5)
# Out:
#      group  grand_tot_interests  interest1  interest2  interest3  interest4  \
# 5097     I                   24        NaN        NaN        NaN        NaN
# 5182     I                   33        NaN        NaN        NaN        NaN
# 1563     C                   42        NaN        NaN        NaN        NaN
# 492      C                   43        1.0        NaN        NaN        NaN
# 3087     P                   45        1.0        NaN        NaN        NaN
#
#       interest5  interest6  interest7  interest8  ...  interest208  \
# 5097        NaN        NaN        NaN        NaN  ...          NaN
# 5182        NaN        1.0        NaN        NaN  ...          NaN
# 1563        NaN        1.0        NaN        NaN  ...          NaN
# 492         1.0        NaN        NaN        NaN  ...          NaN
# 3087        NaN        1.0        NaN        NaN  ...          NaN
#
#       interest209  interest210  interest211  interest212  interest213  \
# ...

# %% [markdown]
# too many missing values

# %% [markdown]
# ### visualization

# %%
sns.countplot(x='group', data=df)
# Out:
# <Axes: xlabel='group', ylabel='count'>

# %%
sns.countplot(x='grand_tot_interests', data=df)
# Out:
# <Axes: xlabel='grand_tot_interests', ylabel='count'>

# %%
sns.relplot(data=df, x="grand_tot_interests", y="interest215", kind='line')
