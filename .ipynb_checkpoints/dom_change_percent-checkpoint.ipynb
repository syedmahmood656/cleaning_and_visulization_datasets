# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('dom_change_percent.csv')

# %%
df.head()
# Out:
#    Unnamed: 0        country price_type            market  \
# 0           0  Cote d'Ivoire     Retail           Abidjan
# 1           1       Cameroon     Retail           Yaund̩
# 2           2       Cameroon     Retail         Bafoussam
# 3           3        Morocco     Retail  National Average
# 4           4  Cote d'Ivoire     Retail           Abidjan
#
#              commodity  percent  post_covid    yearly
# 0            Atti̩k̩      NaN   -0.061538 -0.031746
# 1  Bananas (plantains)      NaN    0.000000  0.000000
# 2  Bananas (plantains)      NaN   -0.305556  0.041667
# 3    Barley (imported)      NaN   -0.034483 -0.034483
# 4   Banana (plantains)      NaN    0.769231  0.232143

# %%
df['country'].nunique()
# Out:
# 88

# %%
df['market'].nunique()
# Out:
# 284

# %%
df['commodity'].nunique()
# Out:
# 84

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1144 entries, 0 to 1143
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1144 non-null   int64
#  1   country     1144 non-null   object
#  2   price_type  1144 non-null   object
#  3   market      1144 non-null   object
#  4   commodity   1144 non-null   object
#  5   percent     0 non-null      float64
#  6   post_covid  1144 non-null   float64
#  7   yearly      1144 non-null   float64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 71.6+ KB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0       0
# country          0
# price_type       0
# market           0
# commodity        0
# percent       1144
# post_covid       0
# yearly           0
# dtype: int64

# %%
df.describe()
# Out:
#        Unnamed: 0  percent   post_covid       yearly
# count  1144.00000      0.0  1144.000000  1144.000000
# mean    571.50000      NaN     0.067674     0.101754
# std     330.38866      NaN     0.280638     0.329084
# min       0.00000      NaN    -0.722222    -0.516129
# 25%     285.75000      NaN    -0.068378    -0.058456
# 50%     571.50000      NaN     0.012739     0.013699
# 75%     857.25000      NaN     0.133976     0.152592
# max    1143.00000      NaN     1.764706     2.264706

# %% [markdown]
# ### visualization

# %%
sns.countplot(x='price_type', data=df)
# Out:
# <Axes: xlabel='price_type', ylabel='count'>

# %%
plt.scatter(df['yearly'],df['post_covid'],color='red',marker='*')

# %%
sns.scatterplot(data=df, x="yearly", y="post_covid", hue ="price_type")
# Out:
# <Axes: xlabel='yearly', ylabel='post_covid'>

# %%
sns.relplot(data=df, x="yearly", y="post_covid", kind='line')

# %%
plt.hist(df['post_covid'],bins=[-0.8,-0.4,0,0.4,0.8,1.2,1.6,2],)
# Out:
# (array([ 17., 436., 587.,  71.,  20.,  12.,   1.]),
#  array([-0.8, -0.4,  0. ,  0.4,  0.8,  1.2,  1.6,  2. ]),
#  <BarContainer object of 7 artists>)
