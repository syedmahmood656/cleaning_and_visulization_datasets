# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('fetal_health.csv')

# %%
df.head()
# Out:
#    baseline value  accelerations  fetal_movement  uterine_contractions  \
# 0           120.0          0.000             0.0                 0.000
# 1           132.0          0.006             0.0                 0.006
# 2           133.0          0.003             0.0                 0.008
# 3           134.0          0.003             0.0                 0.008
# 4           132.0          0.007             0.0                 0.008
#
#    light_decelerations  severe_decelerations  prolongued_decelerations  \
# 0                0.000                   0.0                       0.0
# 1                0.003                   0.0                       0.0
# 2                0.003                   0.0                       0.0
# 3                0.003                   0.0                       0.0
# 4                0.000                   0.0                       0.0
#
#    abnormal_short_term_variability  mean_value_of_short_term_variability  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 22 columns):
#  #   Column                                                  Non-Null Count  Dtype
# ---  ------                                                  --------------  -----
#  0   baseline value                                          2126 non-null   float64
#  1   accelerations                                           2126 non-null   float64
#  2   fetal_movement                                          2126 non-null   float64
#  3   uterine_contractions                                    2126 non-null   float64
#  4   light_decelerations                                     2126 non-null   float64
#  5   severe_decelerations                                    2126 non-null   float64
#  6   prolongued_decelerations                                2126 non-null   float64
#  7   abnormal_short_term_variability                         2126 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# baseline value                                            0
# accelerations                                             0
# fetal_movement                                            0
# uterine_contractions                                      0
# light_decelerations                                       0
# severe_decelerations                                      0
# prolongued_decelerations                                  0
# abnormal_short_term_variability                           0
# mean_value_of_short_term_variability                      0
# percentage_of_time_with_abnormal_long_term_variability    0
# mean_value_of_long_term_variability                       0
# histogram_width                                           0
# histogram_min                                             0
# histogram_max                                             0
# histogram_number_of_peaks                                 0
# histogram_number_of_zeroes                                0
# ...

# %%
df.describe()
# Out:
#        baseline value  accelerations  fetal_movement  uterine_contractions  \
# count     2126.000000    2126.000000     2126.000000           2126.000000
# mean       133.303857       0.003178        0.009481              0.004366
# std          9.840844       0.003866        0.046666              0.002946
# min        106.000000       0.000000        0.000000              0.000000
# 25%        126.000000       0.000000        0.000000              0.002000
# 50%        133.000000       0.002000        0.000000              0.004000
# 75%        140.000000       0.006000        0.003000              0.007000
# max        160.000000       0.019000        0.481000              0.015000
#
#        light_decelerations  severe_decelerations  prolongued_decelerations  \
# count          2126.000000           2126.000000               2126.000000
# mean              0.001889              0.000003                  0.000159
# ...

# %%
df.nunique()
# Out:
# baseline value                                             48
# accelerations                                              20
# fetal_movement                                            102
# uterine_contractions                                       16
# light_decelerations                                        16
# severe_decelerations                                        2
# prolongued_decelerations                                    6
# abnormal_short_term_variability                            75
# mean_value_of_short_term_variability                       57
# percentage_of_time_with_abnormal_long_term_variability     87
# mean_value_of_long_term_variability                       249
# histogram_width                                           154
# histogram_min                                             109
# histogram_max                                              86
# histogram_number_of_peaks                                  18
# ...

# %% [markdown]
# ### visualization

# %%
sns.countplot(x='prolongued_decelerations', data=df)
# Out:
# <Axes: xlabel='prolongued_decelerations', ylabel='count'>

# %%
sns.countplot(x='histogram_number_of_zeroes',data=df)
# Out:
# <Axes: xlabel='histogram_number_of_zeroes', ylabel='count'>

# %%
sns.countplot(x='fetal_health',data=df)
# Out:
# <Axes: xlabel='fetal_health', ylabel='count'>

# %%
sns.barplot(x='fetal_health', y='fetal_movement', data=df)
# Out:
# <Axes: xlabel='fetal_health', ylabel='fetal_movement'>

# %%
plt.scatter(df['histogram_width'],df['mean_value_of_long_term_variability'],color='red',marker='*')

# %%
plt.scatter(df['mean_value_of_long_term_variability'],df['fetal_movement'],color='red',marker='*')

# %%
sns.scatterplot(data=df, x="fetal_movement", y="percentage_of_time_with_abnormal_long_term_variability", hue ="fetal_health")
# Out:
# <Axes: xlabel='fetal_movement', ylabel='percentage_of_time_with_abnormal_long_term_variability'>

# %%
sns.relplot(data=df,x='histogram_width',y='mean_value_of_long_term_variability', hue="severe_decelerations")

# %%
sns.relplot(data=df, x="baseline value", y="accelerations", kind='line')

# %%
df.sample(5)
# Out:
#       baseline value  accelerations  fetal_movement  uterine_contractions  \
# 1022           135.0          0.002           0.000                 0.006
# 286            143.0          0.000           0.002                 0.000
# 1869           138.0          0.006           0.000                 0.003
# 597            148.0          0.000           0.003                 0.005
# 390            129.0          0.010           0.043                 0.003
#
#       light_decelerations  severe_decelerations  prolongued_decelerations  \
# 1022                0.000                   0.0                       0.0
# 286                 0.000                   0.0                       0.0
# 1869                0.004                   0.0                       0.0
# 597                 0.000                   0.0                       0.0
# 390                 0.000                   0.0                       0.0
#
# ...

# %%
df['talk_time'].nunique()
# Out:
# 19
