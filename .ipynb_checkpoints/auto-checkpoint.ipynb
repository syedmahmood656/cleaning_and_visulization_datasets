# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('auto.csv')

# %%
df.head()
# Out:
#    3    ?  alfa-romero  gas  std   two  convertible  rwd  front  88.6  ...  \
# 0  3    ?  alfa-romero  gas  std   two  convertible  rwd  front  88.6  ...
# 1  1    ?  alfa-romero  gas  std   two    hatchback  rwd  front  94.5  ...
# 2  2  164         audi  gas  std  four        sedan  fwd  front  99.8  ...
# 3  2  164         audi  gas  std  four        sedan  4wd  front  99.4  ...
# 4  2    ?         audi  gas  std   two        sedan  fwd  front  99.8  ...
#
#    130  mpfi  3.47  2.68   9.0  111  5000  21  27  13495
# 0  130  mpfi  3.47  2.68   9.0  111  5000  21  27  16500
# 1  152  mpfi  2.68  3.47   9.0  154  5000  19  26  16500
# 2  109  mpfi  3.19  3.40  10.0  102  5500  24  30  13950
# 3  136  mpfi  3.19  3.40   8.0  115  5500  18  22  17450
# 4  136  mpfi  3.19  3.40   8.5  110  5500  19  25  15250
#
# [5 rows x 26 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204 entries, 0 to 203
# Data columns (total 26 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   3            204 non-null    int64
#  1   ?            204 non-null    object
#  2   alfa-romero  204 non-null    object
#  3   gas          204 non-null    object
#  4   std          204 non-null    object
#  5   two          204 non-null    object
#  6   convertible  204 non-null    object
#  7   rwd          204 non-null    object
#  8   front        204 non-null    object
#  9   88.6         204 non-null    float64
#  10  168.8        204 non-null    float64
#  11  64.1         204 non-null    float64
#  12  48.8         204 non-null    float64
#  13  2548         204 non-null    int64
#  14  dohc         204 non-null    object
#  15  four         204 non-null    object
#  16  130          204 non-null    int64
#  17  mpfi         204 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# 3              0
# ?              0
# alfa-romero    0
# gas            0
# std            0
# two            0
# convertible    0
# rwd            0
# front          0
# 88.6           0
# 168.8          0
# 64.1           0
# 48.8           0
# 2548           0
# dohc           0
# four           0
# 130            0
# mpfi           0
# 3.47           0
# 2.68           0
# 9.0            0
# 111            0
# 5000           0
# 21             0
# 27             0
# 13495          0
# dtype: int64

# %%
df.describe()
# Out:
#                 3        88.6       168.8        64.1        48.8  \
# count  204.000000  204.000000  204.000000  204.000000  204.000000
# mean     0.823529   98.806373  174.075000   65.916667   53.749020
# std      1.239035    5.994144   12.362123    2.146716    2.424901
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.075000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.200000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#               2548         130         9.0          21          27
# count   204.000000  204.000000  204.000000  204.000000  204.000000
# mean   2555.602941  126.892157   10.148137   25.240196   30.769608
# std     521.960820   41.744569    3.981000    6.551513    6.898337
# min    1488.000000   61.000000    7.000000   13.000000   16.000000
# ...

# %%
df.nunique()
# Out:
# 3                6
# ?               52
# alfa-romero     22
# gas              2
# std              2
# two              3
# convertible      5
# rwd              3
# front            2
# 88.6            53
# 168.8           75
# 64.1            44
# 48.8            49
# 2548           171
# dohc             7
# four             7
# 130             44
# mpfi             8
# 3.47            39
# 2.68            37
# 9.0             32
# 111             60
# 5000            24
# 21              29
# 27              30
# 13495          186
# dtype: int64

# %%
df['four']
# Out:
# 0      four
# 1       six
# 2      four
# 3      five
# 4      five
#        ...
# 199    four
# 200    four
# 201     six
# 202     six
# 203    four
# Name: four, Length: 204, dtype: object

# %% [markdown]
# ### visualization

# %%
sns.countplot(x='convertible', data=df)
# Out:
# <Axes: xlabel='convertible', ylabel='count'>

# %%
sns.countplot(x='mpfi',data=df)
# Out:
# <Axes: xlabel='mpfi', ylabel='count'>

# %%
sns.countplot(x='four',data=df)
# Out:
# <Axes: xlabel='four', ylabel='count'>

# %%
sns.barplot(x='gas', y='5000', data=df)
# Out:
# <Axes: xlabel='gas', ylabel='5000'>

# %%
plt.scatter(df['21'],df['27'],color='red',marker='*')

# %%
plt.scatter(df['130'],df['2548'],color='red',marker='*')

# %%
plt.scatter(df['48.8'],df['9.0'],color='red',marker='*')

# %%
sns.scatterplot(data=df, x="2548", y="88.6", hue ="convertible")
# Out:
# <Axes: xlabel='2548', ylabel='88.6'>

# %%
sns.relplot(data=df, x="168.8", y="48.8", hue="std")

# %%
sns.relplot(data=df, x="168.8", y="48.8", hue="gas")

# %%
df.sample(5)
# Out:
#      3    ? alfa-romero  gas  std   two convertible  rwd  front   88.6  ...  \
# 36   0  106       honda  gas  std   two   hatchback  fwd  front   96.5  ...
# 176 -1   65      toyota  gas  std  four   hatchback  fwd  front  102.4  ...
# 29   2  137       honda  gas  std   two   hatchback  fwd  front   86.6  ...
# 21   1  118       dodge  gas  std   two   hatchback  fwd  front   93.7  ...
# 63   0  115       mazda  gas  std  four   hatchback  fwd  front   98.8  ...
#
#      130  mpfi  3.47  2.68  9.0 111  5000  21  27  13495
# 36   110  1bbl  3.15  3.58  9.0  86  5800  27  33   7895
# 176  122  mpfi  3.31  3.54  8.7  92  4200  27  32  11248
# 29    92  1bbl  2.91  3.41  9.6  58  4800  49  54   6479
# 21    90  2bbl  2.97  3.23  9.4  68  5500  31  38   6377
# 63   122  2bbl  3.39  3.39  8.6  84  4800  26  32  11245
#
# [5 rows x 26 columns]
