# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('abalone.csv')

# %%
df.head()
# Out:
#   Sex  Length  Diameter  Height  Whole weight  Shucked weight  Viscera weight  \
# 0   M   0.455     0.365   0.095        0.5140          0.2245          0.1010
# 1   M   0.350     0.265   0.090        0.2255          0.0995          0.0485
# 2   F   0.530     0.420   0.135        0.6770          0.2565          0.1415
# 3   M   0.440     0.365   0.125        0.5160          0.2155          0.1140
# 4   I   0.330     0.255   0.080        0.2050          0.0895          0.0395
#
#    Shell weight  Rings
# 0         0.150     15
# 1         0.070      7
# 2         0.210      9
# 3         0.155     10
# 4         0.055      7

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4177 entries, 0 to 4176
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             4177 non-null   object
#  1   Length          4177 non-null   float64
#  2   Diameter        4177 non-null   float64
#  3   Height          4177 non-null   float64
#  4   Whole weight    4177 non-null   float64
#  5   Shucked weight  4177 non-null   float64
#  6   Viscera weight  4177 non-null   float64
#  7   Shell weight    4177 non-null   float64
#  8   Rings           4177 non-null   int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 293.8+ KB

# %%
df.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Whole weight      0
# Shucked weight    0
# Viscera weight    0
# Shell weight      0
# Rings             0
# dtype: int64

# %%
df.nunique()
# Out:
# Sex                  3
# Length             134
# Diameter           111
# Height              51
# Whole weight      2429
# Shucked weight    1515
# Viscera weight     880
# Shell weight       926
# Rings               28
# dtype: int64

# %%
df.describe()
# Out:
#             Length     Diameter       Height  Whole weight  Shucked weight  \
# count  4177.000000  4177.000000  4177.000000   4177.000000     4177.000000
# mean      0.523992     0.407881     0.139516      0.828742        0.359367
# std       0.120093     0.099240     0.041827      0.490389        0.221963
# min       0.075000     0.055000     0.000000      0.002000        0.001000
# 25%       0.450000     0.350000     0.115000      0.441500        0.186000
# 50%       0.545000     0.425000     0.140000      0.799500        0.336000
# 75%       0.615000     0.480000     0.165000      1.153000        0.502000
# max       0.815000     0.650000     1.130000      2.825500        1.488000
#
#        Viscera weight  Shell weight        Rings
# count     4177.000000   4177.000000  4177.000000
# mean         0.180594      0.238831     9.933684
# std          0.109614      0.139203     3.224169
# min          0.000500      0.001500     1.000000
# ...

# %% [markdown]
# ### visualization

# %%
sns.countplot(x='Rings', data=df)
# Out:
# <Axes: xlabel='Rings', ylabel='count'>

# %%
sns.countplot(x='Sex',data=df)
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
sns.barplot(x='touch_screen', y='battery_power', data=df)
# Out:
# <Axes: xlabel='touch_screen', ylabel='battery_power'>

# %%
plt.scatter(df['Length'],df['Diameter'],color='red',marker='*')

# %%
plt.scatter(df['Height'],df['Whole weight'],color='red',marker='*')

# %%
plt.scatter(df['Shell weight'],df['Shucked weight'],color='red')

# %%
plt.scatter(df['Shell weight'],df['Viscera weight'],color='red')

# %%
plt.scatter(df['Shell weight'],df['Length'],color='red',marker='*')

# %%
sns.scatterplot(data=df, x='Shell weight',y='Shucked weight', hue ="Sex")
# Out:
# <Axes: xlabel='Shell weight', ylabel='Shucked weight'>

# %%
sns.relplot(data=df, x="Rings", y="Length", kind='line')

# %%
plt.bar(df['Diameter'],df['Whole weight'],color='red')
# Out:
# <BarContainer object of 4177 artists>

# %%
df.sample(5)
# Out:
#      Sex  Length  Diameter  Height  Whole weight  Shucked weight  \
# 344    F   0.460     0.425   0.155        0.7460          0.3005
# 3921   M   0.375     0.280   0.095        0.2225          0.0875
# 1747   F   0.700     0.535   0.175        1.7730          0.6805
# 1217   I   0.315     0.230   0.080        0.1375          0.0545
# 3859   F   0.570     0.440   0.190        1.0180          0.4470
#
#       Viscera weight  Shell weight  Rings
# 344            0.152        0.2400      8
# 3921           0.043        0.0800     10
# 1747           0.480        0.5120     15
# 1217           0.031        0.0445      5
# 3859           0.207        0.2650      9
