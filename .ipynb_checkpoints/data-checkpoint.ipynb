# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data.csv')

# %%
df.head()
# Out:
#    Unnamed: 0   X1   X2   X3   X4   X5   X6   X7   X8   X9  ...  X170  X171  \
# 0  X21.V1.791  135  190  229  223  192  125   55   -9  -33  ...   -17   -15
# 1  X15.V1.924  386  382  356  331  320  315  307  272  244  ...   164   150
# 2     X8.V1.1  -32  -39  -47  -37  -32  -36  -57  -73  -85  ...    57    64
# 3   X16.V1.60 -105 -101  -96  -92  -89  -95 -102 -100  -87  ...   -82   -81
# 4   X20.V1.54   -9  -65  -98 -102  -78  -48  -16    0  -21  ...     4     2
#
#    X172  X173  X174  X175  X176  X177  X178  y
# 0   -31   -77  -103  -127  -116   -83   -51  4
# 1   146   152   157   156   154   143   129  1
# 2    48    19   -12   -30   -35   -35   -36  5
# 3   -80   -77   -85   -77   -72   -69   -65  5
# 4   -12   -32   -41   -65   -83   -89   -73  5
#
# [5 rows x 180 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11500 entries, 0 to 11499
# Columns: 180 entries, Unnamed: 0 to y
# dtypes: int64(179), object(1)
# memory usage: 15.8+ MB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# X1            0
# X2            0
# X3            0
# X4            0
#              ..
# X175          0
# X176          0
# X177          0
# X178          0
# y             0
# Length: 180, dtype: int64

# %%
df.describe()
# Out:
#                  X1            X2            X3            X4            X5  \
# count  11500.000000  11500.000000  11500.000000  11500.000000  11500.000000
# mean     -11.581391    -10.911565    -10.187130     -9.143043     -8.009739
# std      165.626284    166.059609    163.524317    161.269041    160.998007
# min    -1839.000000  -1838.000000  -1835.000000  -1845.000000  -1791.000000
# 25%      -54.000000    -55.000000    -54.000000    -54.000000    -54.000000
# 50%       -8.000000     -8.000000     -7.000000     -8.000000     -8.000000
# 75%       34.000000     35.000000     36.000000     36.000000     35.000000
# max     1726.000000   1713.000000   1697.000000   1612.000000   1518.000000
#
#                  X6            X7           X8           X9           X10  \
# count  11500.000000  11500.000000  11500.00000  11500.00000  11500.000000
# mean      -7.003478     -6.502087     -6.68713     -6.55800     -6.168435
# ...

# %%
df.nunique()
# Out:
# Unnamed: 0    11500
# X1             1084
# X2             1077
# X3             1083
# X4             1075
#               ...
# X175           1053
# X176           1055
# X177           1070
# X178           1071
# y                 5
# Length: 180, dtype: int64

# %% [markdown]
# ### visualization

# %%
sns.countplot(x='y', data=df)
# Out:
# <Axes: xlabel='y', ylabel='count'>

# %%
sns.barplot(x='y', y='X120', data=df)
# Out:
# <Axes: xlabel='y', ylabel='X120'>

# %%
plt.scatter(df['X48'],df['X40'],color='red',marker='*')

# %%
plt.scatter(df['X28'],df['X4'],color='red',marker='*')

# %%
plt.scatter(df['X15'],df['X45'],color='red',marker='*')

# %%
sns.scatterplot(data=df, x="X78", y="X57", hue ="y")
# Out:
# <Axes: xlabel='X78', ylabel='X57'>

# %%
sns.scatterplot(data=df, x="X111", y="X55", hue ="y")
# Out:
# <Axes: xlabel='X111', ylabel='X55'>

# %%
sns.relplot(data=df, x="X85", y="X92", kind='line')

# %%
df.sample(5)
# Out:
#        Unnamed: 0   X1   X2   X3   X4   X5   X6   X7   X8  X9  ...  X170  \
# 10107  X18.V1.181    7  -16  -35  -55  -69  -81  -78  -59 -44  ...   -60
# 8872    X7.V1.743   13   18   17   13   17   14   12   10  12  ...    23
# 10451   X22.V1.37  -28  -49  -57  -48  -27  -31  -38  -63 -71  ...   -99
# 1926   X22.V1.714 -140 -141 -141 -141 -134 -124 -111 -101 -93  ...  -134
# 9437   X16.V1.551   26   35   26    4  -23  -45  -61  -49 -31  ...  -128
#
#        X171  X172  X173  X174  X175  X176  X177  X178  y
# 10107   -97  -132  -149  -146  -142  -130  -112   -81  4
# 8872     22    26    35    43    34    23    10     3  2
# 10451   -87   -68   -49   -42   -46   -62   -72   -96  5
# 1926   -139  -145  -147  -150  -151  -152  -147  -137  2
# 9437   -117  -105   -95   -79   -59   -40   -28    -9  4
#
# [5 rows x 180 columns]
