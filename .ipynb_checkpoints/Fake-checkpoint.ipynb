# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Fake.csv')

# %%
df.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
df.sample(10)
# Out:
#                                                    title  \
# 2730    REPORT: Jared Kushner ‘F**king Furious’ Over ...
# 5329    P*ssed Off Musicians Sing To Trump: ‘Stop Usi...
# 9704   DIAMOND AND SILK Clap-Back at Eminem: ‘When yo...
# 5867    Newt Gingrich: Forget NSA Spying, Bring Back ...
# 1062    Betsy Devos Just Put A For-Profit Credit Card...
# 17037  IT’S CHRISTMAS IN OCTOBER: American Debt Is $1...
# 12603  TRUMP LAUNCHES GRENADE AT TAX AND SPEND WASHIN...
# 11194  JUST IN TIME FOR RE-ELECTION…Angela Merkel’s C...
# 15653  OBAMA TO GRANT WORK PERMITS FOR SPOUSES OF ILL...
# 9437   WOW! JEB BUSH Claims Roy Moore Should “Step As...
#
#                                                     text          subject  \
# 2730   Many people have looked to Donald Trump s son-...             News
# 5329   Throughout his campaign, Donald Trump has been...             News
# 9704   In case you haven t heard about the nasty Emin...         politics
# 5867   Trump fanboy Newt Gingrich thinks that the bes...             News
# 1062   On Tuesday, Education Secretary Betsy Devos an...             News
# 17037  This one sentence should scare every taxpaying...  Government News
# 12603                                                            politics
# 11194  Here are a few facts:Sexual violence in German...         politics
# 15653  40% of Americans have given up looking for wor...         politics
# 9437   Monday on CNBC, former Gov. Jeb Bush (R-FL) sa...         politics
#
#                    date
# 2730   February 2, 2017
# 5329      July 25, 2016
# 9704       Oct 12, 2017
# 5867      June 15, 2016
# 1062      June 21, 2017
# 17037      Oct 14, 2015
# 12603      Oct 27, 2016
# 11194       Apr 5, 2017
# 15653      May 21, 2015
# 9437       Nov 13, 2017

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23481 entries, 0 to 23480
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   title    23481 non-null  object
#  1   text     23481 non-null  object
#  2   subject  23481 non-null  object
#  3   date     23481 non-null  object
# dtypes: object(4)
# memory usage: 733.9+ KB

# %%
df.isnull().sum()
# Out:
# title      0
# text       0
# subject    0
# date       0
# dtype: int64

# %%
df.describe()
# Out:
#                                                     title   text subject  \
# count                                               23481  23481   23481
# unique                                              17903  17455       6
# top     MEDIA IGNORES Time That Bill Clinton FIRED His...           News
# freq                                                    6    626    9050
#
#                 date
# count          23481
# unique          1681
# top     May 10, 2017
# freq              46

# %%
df.nunique()
# Out:
# title      17903
# text       17455
# subject        6
# date        1681
# dtype: int64

# %% [markdown]
# ### visualization

# %%
sns.countplot(x="subject", data=df)
# Out:
# <Axes: xlabel='subject', ylabel='count'>

# %%
sns.relplot(data=df, x="date", y="subject", kind='line')
# Out:
# C:\Users\mohammed junaid\anaconda3\Lib\site-packages\seaborn\axisgrid.py:123: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all Axes decorations.
#   self._figure.tight_layout(*args, **kwargs)

# %%
y = df['subject'].value_counts()
plt.figure(figsize=(8, 6))
plt.pie(y, labels=y.index, autopct='%1.1f%%', pctdistance=0.85, colors=sns.color_palette('Set2'))

plt.show()
